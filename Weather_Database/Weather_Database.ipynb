# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 719

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | leningradskiy
# Processing Record 6 of Set 1 | dwarka
# Processing Record 7 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 1 | jiangyou
# Processing Record 9 of Set 1 | port hardy
# Processing Record 10 of Set 1 | salalah
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | nanortalik
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | te anau
# Processing Record 18 of Set 1 | chunskiy
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | bairiki
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | cockburn town
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | labuhan
# Processing Record 27 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | tommot
# Processing Record 32 of Set 1 | mackay
# Processing Record 33 of Set 1 | qasigiannguit
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | clyde river
# Processing Record 36 of Set 1 | sorong
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | ban dung
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | geraldton
# Processing Record 41 of Set 1 | conde
# Processing Record 42 of Set 1 | vila franca do campo
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | duz
# City not found. Skipping...
# Processing Record 45 of Set 1 | oistins
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | sobolevo
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | bosaso
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | lompoc
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 2 | fort oglethorpe
# Processing Record 5 of Set 2 | quthing
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | presidencia roque saenz pena
# Processing Record 9 of Set 2 | cherskiy
# Processing Record 10 of Set 2 | rutland
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | gat
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | pacifica
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | bo rai
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | cidreira
# Processing Record 21 of Set 2 | sept-iles
# Processing Record 22 of Set 2 | evensk
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | palana
# Processing Record 26 of Set 2 | henties bay
# Processing Record 27 of Set 2 | pemangkat
# Processing Record 28 of Set 2 | san vicente
# Processing Record 29 of Set 2 | zhigansk
# Processing Record 30 of Set 2 | ketchikan
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | biratnagar
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | passy
# Processing Record 37 of Set 2 | merauke
# Processing Record 38 of Set 2 | atar
# Processing Record 39 of Set 2 | srednekolymsk
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | colares
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | borogontsy
# Processing Record 44 of Set 2 | inhambane
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | houma
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | hualmay
# Processing Record 49 of Set 2 | tabuk
# Processing Record 50 of Set 2 | lukulu
# City not found. Skipping...
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 3 | mount gambier
# Processing Record 4 of Set 3 | babu
# Processing Record 5 of Set 3 | altyn-topkan
# Processing Record 6 of Set 3 | lingao
# Processing Record 7 of Set 3 | cartagena del chaira
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | banyo
# Processing Record 10 of Set 3 | devils lake
# Processing Record 11 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 12 of Set 3 | bogalusa
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | birao
# Processing Record 16 of Set 3 | akdepe
# Processing Record 17 of Set 3 | middle island
# Processing Record 18 of Set 3 | lichtenfels
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | college
# Processing Record 21 of Set 3 | papara
# Processing Record 22 of Set 3 | tamandare
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | buraydah
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | katsuura
# Processing Record 28 of Set 3 | eureka
# Processing Record 29 of Set 3 | blonduos
# City not found. Skipping...
# Processing Record 30 of Set 3 | barranca
# Processing Record 31 of Set 3 | san cristobal
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | lakeway
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | zalakomar
# Processing Record 37 of Set 3 | santa vitoria do palmar
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | khani
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | sfantu gheorghe
# Processing Record 42 of Set 3 | porto walter
# Processing Record 43 of Set 3 | thinadhoo
# Processing Record 44 of Set 3 | kasongo
# Processing Record 45 of Set 3 | nam som
# Processing Record 46 of Set 3 | pelotas
# Processing Record 47 of Set 3 | putina
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | roros
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | ambilobe
# Processing Record 2 of Set 4 | daru
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | skjervoy
# Processing Record 5 of Set 4 | port augusta
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | adrar
# Processing Record 9 of Set 4 | barentu
# Processing Record 10 of Set 4 | rawson
# Processing Record 11 of Set 4 | aleksandrov gay
# Processing Record 12 of Set 4 | hobart
# Processing Record 13 of Set 4 | lima
# Processing Record 14 of Set 4 | broken hill
# Processing Record 15 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 4 | tiznit
# Processing Record 17 of Set 4 | poggibonsi
# Processing Record 18 of Set 4 | ende
# Processing Record 19 of Set 4 | omboue
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | constitucion
# Processing Record 22 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 4 | paita
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | dawei
# Processing Record 27 of Set 4 | lata
# Processing Record 28 of Set 4 | kulachi
# Processing Record 29 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | puerto leguizamo
# Processing Record 32 of Set 4 | butaritari
# Processing Record 33 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 4 | aripuana
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | laguna
# Processing Record 38 of Set 4 | kjopsvik
# Processing Record 39 of Set 4 | honiara
# Processing Record 40 of Set 4 | pangkalanbuun
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | dinghai
# Processing Record 43 of Set 4 | malpe
# Processing Record 44 of Set 4 | kurumkan
# Processing Record 45 of Set 4 | luanda
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | juneau
# Processing Record 48 of Set 4 | scarborough
# Processing Record 49 of Set 4 | qaqortoq
# Processing Record 50 of Set 4 | lafia
# Processing Record 1 of Set 5 | pontes e lacerda
# Processing Record 2 of Set 5 | calama
# Processing Record 3 of Set 5 | mayo
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | krasnaya gora
# Processing Record 6 of Set 5 | beckley
# Processing Record 7 of Set 5 | wagga wagga
# Processing Record 8 of Set 5 | yulara
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | parainen
# Processing Record 11 of Set 5 | griffith
# Processing Record 12 of Set 5 | kuryk
# Processing Record 13 of Set 5 | valparaiso
# Processing Record 14 of Set 5 | impfondo
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | macia
# Processing Record 17 of Set 5 | waingapu
# Processing Record 18 of Set 5 | villa carlos paz
# Processing Record 19 of Set 5 | ilula
# Processing Record 20 of Set 5 | pleshanovo
# Processing Record 21 of Set 5 | inirida
# Processing Record 22 of Set 5 | chokurdakh
# Processing Record 23 of Set 5 | goderich
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | burica
# City not found. Skipping...
# Processing Record 26 of Set 5 | tucuman
# Processing Record 27 of Set 5 | san carlos de bariloche
# Processing Record 28 of Set 5 | ancud
# Processing Record 29 of Set 5 | marawi
# Processing Record 30 of Set 5 | nemuro
# Processing Record 31 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 5 | iqaluit
# Processing Record 33 of Set 5 | san patricio
# Processing Record 34 of Set 5 | sorland
# Processing Record 35 of Set 5 | kununurra
# Processing Record 36 of Set 5 | villaviciosa
# Processing Record 37 of Set 5 | naze
# Processing Record 38 of Set 5 | mbour
# Processing Record 39 of Set 5 | hamilton
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | kholodnyy
# Processing Record 42 of Set 5 | coquimbo
# Processing Record 43 of Set 5 | ponta do sol
# Processing Record 44 of Set 5 | kota bahru
# Processing Record 45 of Set 5 | jatibonico
# Processing Record 46 of Set 5 | kijang
# Processing Record 47 of Set 5 | praia
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | olafsvik
# Processing Record 50 of Set 5 | kuytun
# Processing Record 1 of Set 6 | awbari
# Processing Record 2 of Set 6 | avera
# Processing Record 3 of Set 6 | port-cartier
# Processing Record 4 of Set 6 | camacha
# Processing Record 5 of Set 6 | itaqui
# Processing Record 6 of Set 6 | eenhana
# Processing Record 7 of Set 6 | boyuibe
# Processing Record 8 of Set 6 | kupang
# Processing Record 9 of Set 6 | ayan
# Processing Record 10 of Set 6 | vallenar
# Processing Record 11 of Set 6 | kodiak
# Processing Record 12 of Set 6 | alexandria
# Processing Record 13 of Set 6 | jalu
# Processing Record 14 of Set 6 | pisco
# Processing Record 15 of Set 6 | arlit
# Processing Record 16 of Set 6 | belovo
# Processing Record 17 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | westport
# Processing Record 20 of Set 6 | birkeland
# Processing Record 21 of Set 6 | ajuchitlan
# Processing Record 22 of Set 6 | rocha
# Processing Record 23 of Set 6 | ukiah
# Processing Record 24 of Set 6 | provideniya
# Processing Record 25 of Set 6 | norsup
# Processing Record 26 of Set 6 | arraial do cabo
# Processing Record 27 of Set 6 | alofi
# Processing Record 28 of Set 6 | irpa irpa
# Processing Record 29 of Set 6 | suoyarvi
# Processing Record 30 of Set 6 | neuquen
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | kavaratti
# Processing Record 33 of Set 6 | garowe
# Processing Record 34 of Set 6 | sumbe
# Processing Record 35 of Set 6 | gonbad-e qabus
# Processing Record 36 of Set 6 | pencaitland
# Processing Record 37 of Set 6 | husavik
# Processing Record 38 of Set 6 | victoria
# Processing Record 39 of Set 6 | hovd
# Processing Record 40 of Set 6 | nedjo
# Processing Record 41 of Set 6 | chiang khong
# Processing Record 42 of Set 6 | bimbo
# Processing Record 43 of Set 6 | luebo
# Processing Record 44 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 6 | killybegs
# Processing Record 46 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 47 of Set 6 | kharp
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | lavrentiya
# Processing Record 50 of Set 6 | ambala
# Processing Record 1 of Set 7 | doha
# Processing Record 2 of Set 7 | sidi ali
# Processing Record 3 of Set 7 | taltal
# Processing Record 4 of Set 7 | burnie
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | kloulklubed
# Processing Record 7 of Set 7 | taldan
# Processing Record 8 of Set 7 | huarmey
# Processing Record 9 of Set 7 | arua
# Processing Record 10 of Set 7 | bathsheba
# Processing Record 11 of Set 7 | kosa
# Processing Record 12 of Set 7 | nuuk
# Processing Record 13 of Set 7 | pervomayskoye
# Processing Record 14 of Set 7 | marzuq
# Processing Record 15 of Set 7 | manokwari
# Processing Record 16 of Set 7 | bowen
# Processing Record 17 of Set 7 | ballina
# Processing Record 18 of Set 7 | taoudenni
# Processing Record 19 of Set 7 | castro
# Processing Record 20 of Set 7 | narasannapeta
# Processing Record 21 of Set 7 | ous
# Processing Record 22 of Set 7 | kaitangata
# Processing Record 23 of Set 7 | waipawa
# Processing Record 24 of Set 7 | grindavik
# Processing Record 25 of Set 7 | praia da vitoria
# Processing Record 26 of Set 7 | wangqing
# Processing Record 27 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 7 | humboldt
# Processing Record 29 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 30 of Set 7 | madimba
# Processing Record 31 of Set 7 | prince rupert
# Processing Record 32 of Set 7 | pingliang
# Processing Record 33 of Set 7 | vrutky
# Processing Record 34 of Set 7 | dumra
# Processing Record 35 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 7 | caceres
# Processing Record 37 of Set 7 | pagudpud
# Processing Record 38 of Set 7 | alice springs
# Processing Record 39 of Set 7 | sao filipe
# Processing Record 40 of Set 7 | colquechaca
# Processing Record 41 of Set 7 | saint-joseph
# Processing Record 42 of Set 7 | wakkanai
# Processing Record 43 of Set 7 | sehithwa
# Processing Record 44 of Set 7 | finote selam
# Processing Record 45 of Set 7 | jaltenango
# Processing Record 46 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 7 | moose factory
# Processing Record 48 of Set 7 | faanui
# Processing Record 49 of Set 7 | muzhi
# Processing Record 50 of Set 7 | sotuta
# Processing Record 1 of Set 8 | ashington
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | shimoda
# Processing Record 4 of Set 8 | tena
# Processing Record 5 of Set 8 | libourne
# Processing Record 6 of Set 8 | kilinochchi
# Processing Record 7 of Set 8 | nome
# Processing Record 8 of Set 8 | casper
# Processing Record 9 of Set 8 | kaitong
# Processing Record 10 of Set 8 | sabang
# Processing Record 11 of Set 8 | dingle
# Processing Record 12 of Set 8 | hofn
# Processing Record 13 of Set 8 | yenagoa
# Processing Record 14 of Set 8 | vozhega
# Processing Record 15 of Set 8 | payakumbuh
# Processing Record 16 of Set 8 | bonfim
# Processing Record 17 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 8 | mangrol
# Processing Record 19 of Set 8 | asau
# Processing Record 20 of Set 8 | korla
# Processing Record 21 of Set 8 | awjilah
# Processing Record 22 of Set 8 | vila velha
# Processing Record 23 of Set 8 | tibiri
# Processing Record 24 of Set 8 | tabory
# Processing Record 25 of Set 8 | tsnori
# Processing Record 26 of Set 8 | touros
# Processing Record 27 of Set 8 | suhbaatar
# Processing Record 28 of Set 8 | guerrero negro
# Processing Record 29 of Set 8 | phnum penh
# City not found. Skipping...
# Processing Record 30 of Set 8 | faya
# Processing Record 31 of Set 8 | tuatapere
# Processing Record 32 of Set 8 | voi
# Processing Record 33 of Set 8 | suntar
# Processing Record 34 of Set 8 | bahia de caraquez
# Processing Record 35 of Set 8 | half moon bay
# Processing Record 36 of Set 8 | goma
# Processing Record 37 of Set 8 | nishihara
# Processing Record 38 of Set 8 | arcachon
# Processing Record 39 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 8 | saint anthony
# Processing Record 41 of Set 8 | pianco
# Processing Record 42 of Set 8 | la ronge
# Processing Record 43 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 8 | bara
# Processing Record 45 of Set 8 | port macquarie
# Processing Record 46 of Set 8 | alberobello
# Processing Record 47 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 8 | komsomolskiy
# Processing Record 49 of Set 8 | isilkul
# Processing Record 50 of Set 8 | namibe
# Processing Record 1 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 9 | bonavista
# Processing Record 3 of Set 9 | talcahuano
# Processing Record 4 of Set 9 | caravelas
# Processing Record 5 of Set 9 | ejido
# Processing Record 6 of Set 9 | makakilo city
# Processing Record 7 of Set 9 | egvekinot
# Processing Record 8 of Set 9 | seleron
# Processing Record 9 of Set 9 | kitsuki
# Processing Record 10 of Set 9 | coihueco
# Processing Record 11 of Set 9 | brae
# Processing Record 12 of Set 9 | richards bay
# Processing Record 13 of Set 9 | bastia
# Processing Record 14 of Set 9 | knysna
# Processing Record 15 of Set 9 | eskil
# Processing Record 16 of Set 9 | mehamn
# Processing Record 17 of Set 9 | grimshaw
# Processing Record 18 of Set 9 | belmonte
# Processing Record 19 of Set 9 | rochegda
# Processing Record 20 of Set 9 | aksu
# Processing Record 21 of Set 9 | colombia
# Processing Record 22 of Set 9 | bambous virieux
# Processing Record 23 of Set 9 | pangnirtung
# Processing Record 24 of Set 9 | menongue
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | cayenne
# Processing Record 27 of Set 9 | gilgil
# City not found. Skipping...
# Processing Record 28 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 29 of Set 9 | iturbe
# Processing Record 30 of Set 9 | altay
# Processing Record 31 of Set 9 | sawakin
# Processing Record 32 of Set 9 | tabou
# Processing Record 33 of Set 9 | tual
# Processing Record 34 of Set 9 | kisangani
# Processing Record 35 of Set 9 | anzoategui
# Processing Record 36 of Set 9 | port hedland
# Processing Record 37 of Set 9 | kodinsk
# Processing Record 38 of Set 9 | riaba
# City not found. Skipping...
# Processing Record 39 of Set 9 | yadgir
# Processing Record 40 of Set 9 | poum
# Processing Record 41 of Set 9 | wamba
# Processing Record 42 of Set 9 | nagato
# Processing Record 43 of Set 9 | port lincoln
# Processing Record 44 of Set 9 | cacak
# Processing Record 45 of Set 9 | tromso
# Processing Record 46 of Set 9 | padang
# Processing Record 47 of Set 9 | okahandja
# Processing Record 48 of Set 9 | margate
# Processing Record 49 of Set 9 | baillif
# Processing Record 50 of Set 9 | cotonou
# Processing Record 1 of Set 10 | hatillo
# Processing Record 2 of Set 10 | moshny
# Processing Record 3 of Set 10 | vostok
# Processing Record 4 of Set 10 | luderitz
# Processing Record 5 of Set 10 | wooster
# Processing Record 6 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 10 | coahuayana
# Processing Record 8 of Set 10 | san lorenzo
# Processing Record 9 of Set 10 | karaton
# Processing Record 10 of Set 10 | yeppoon
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | la primavera
# Processing Record 13 of Set 10 | shevchenko
# Processing Record 14 of Set 10 | biloela
# Processing Record 15 of Set 10 | beringovskiy
# Processing Record 16 of Set 10 | abapo
# Processing Record 17 of Set 10 | shenxian
# Processing Record 18 of Set 10 | dicabisagan
# Processing Record 19 of Set 10 | santarem
# Processing Record 20 of Set 10 | tura
# Processing Record 21 of Set 10 | muros
# Processing Record 22 of Set 10 | patrocinio
# Processing Record 23 of Set 10 | hervey bay
# Processing Record 24 of Set 10 | chapais
# Processing Record 25 of Set 10 | mercedes
# Processing Record 26 of Set 10 | lichtenau
# Processing Record 27 of Set 10 | bilibino
# Processing Record 28 of Set 10 | quang ngai
# Processing Record 29 of Set 10 | duku
# Processing Record 30 of Set 10 | ponta grossa
# Processing Record 31 of Set 10 | mahibadhoo
# Processing Record 32 of Set 10 | inuvik
# Processing Record 33 of Set 10 | spring valley
# Processing Record 34 of Set 10 | scottsbluff
# Processing Record 35 of Set 10 | del rio
# Processing Record 36 of Set 10 | grand bank
# Processing Record 37 of Set 10 | thoen
# Processing Record 38 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 10 | tanete
# Processing Record 40 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 10 | quilmana
# Processing Record 42 of Set 10 | batagay-alyta
# Processing Record 43 of Set 10 | lorengau
# Processing Record 44 of Set 10 | solenzo
# Processing Record 45 of Set 10 | uzhur
# Processing Record 46 of Set 10 | pathein
# Processing Record 47 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 48 of Set 10 | itarema
# Processing Record 49 of Set 10 | auki
# Processing Record 50 of Set 10 | aksarka
# Processing Record 1 of Set 11 | basoko
# Processing Record 2 of Set 11 | mankono
# Processing Record 3 of Set 11 | ayagoz
# Processing Record 4 of Set 11 | kruisfontein
# Processing Record 5 of Set 11 | reshetylivka
# Processing Record 6 of Set 11 | kagoro
# Processing Record 7 of Set 11 | maxixe
# Processing Record 8 of Set 11 | golden
# Processing Record 9 of Set 11 | swan hill
# Processing Record 10 of Set 11 | bafoulabe
# Processing Record 11 of Set 11 | soe
# Processing Record 12 of Set 11 | meulaboh
# Processing Record 13 of Set 11 | puerto rondon
# Processing Record 14 of Set 11 | pailon
# Processing Record 15 of Set 11 | oeiras
# Processing Record 16 of Set 11 | mariager
# Processing Record 17 of Set 11 | solnechnyy
# Processing Record 18 of Set 11 | savannakhet
# Processing Record 19 of Set 11 | rudbar
# Processing Record 20 of Set 11 | coolidge
# Processing Record 21 of Set 11 | linxia
# Processing Record 22 of Set 11 | dalby
# Processing Record 23 of Set 11 | makung
# City not found. Skipping...
# Processing Record 24 of Set 11 | aklavik
# Processing Record 25 of Set 11 | udachnyy
# Processing Record 26 of Set 11 | fulton
# Processing Record 27 of Set 11 | nador
# Processing Record 28 of Set 11 | victoria point
# Processing Record 29 of Set 11 | tezu
# Processing Record 30 of Set 11 | kirakira
# Processing Record 31 of Set 11 | kupino
# Processing Record 32 of Set 11 | bonthe
# Processing Record 33 of Set 11 | zalantun
# Processing Record 34 of Set 11 | kobojango
# City not found. Skipping...
# Processing Record 35 of Set 11 | ivdel
# Processing Record 36 of Set 11 | narasapur
# Processing Record 37 of Set 11 | yumen
# Processing Record 38 of Set 11 | amur
# Processing Record 39 of Set 11 | wajir
# Processing Record 40 of Set 11 | wanning
# Processing Record 41 of Set 11 | wagar
# Processing Record 42 of Set 11 | anadyr
# Processing Record 43 of Set 11 | tortoli
# Processing Record 44 of Set 11 | lakselv
# Processing Record 45 of Set 11 | gisborne
# Processing Record 46 of Set 11 | kudahuvadhoo
# Processing Record 47 of Set 11 | tongren
# Processing Record 48 of Set 11 | sola
# Processing Record 49 of Set 11 | tilichiki
# Processing Record 50 of Set 11 | sinnamary
# Processing Record 1 of Set 12 | redmond
# Processing Record 2 of Set 12 | manta
# Processing Record 3 of Set 12 | teguise
# Processing Record 4 of Set 12 | kawalu
# Processing Record 5 of Set 12 | port blair
# Processing Record 6 of Set 12 | beloha
# Processing Record 7 of Set 12 | kattivakkam
# Processing Record 8 of Set 12 | bajil
# Processing Record 9 of Set 12 | sakakah
# Processing Record 10 of Set 12 | kiruna
# Processing Record 11 of Set 12 | linares
# Processing Record 12 of Set 12 | fort nelson
# Processing Record 13 of Set 12 | san policarpo
# Processing Record 14 of Set 12 | ullapool
# Processing Record 15 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 12 | boende
# Processing Record 17 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 12 | jega
# Processing Record 19 of Set 12 | namatanai
# Processing Record 20 of Set 12 | arsenyev
# Processing Record 21 of Set 12 | katherine
# Processing Record 22 of Set 12 | mecca
# Processing Record 23 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 12 | mirina
# City not found. Skipping...
# Processing Record 25 of Set 12 | dongying
# Processing Record 26 of Set 12 | chumphon
# Processing Record 27 of Set 12 | saint-augustin
# Processing Record 28 of Set 12 | sapapalii
# City not found. Skipping...
# Processing Record 29 of Set 12 | yakeshi
# Processing Record 30 of Set 12 | sibu
# Processing Record 31 of Set 12 | dayong
# Processing Record 32 of Set 12 | gigmoto
# Processing Record 33 of Set 12 | nouadhibou
# Processing Record 34 of Set 12 | san bartolome de tirajana
# Processing Record 35 of Set 12 | goundam
# Processing Record 36 of Set 12 | shingu
# Processing Record 37 of Set 12 | buala
# Processing Record 38 of Set 12 | saint-georges
# Processing Record 39 of Set 12 | erenhot
# Processing Record 40 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 12 | pontianak
# Processing Record 42 of Set 12 | mogadishu
# Processing Record 43 of Set 12 | ouesso
# Processing Record 44 of Set 12 | indramayu
# Processing Record 45 of Set 12 | obo
# Processing Record 46 of Set 12 | kaura namoda
# Processing Record 47 of Set 12 | raton
# Processing Record 48 of Set 12 | santa maria
# Processing Record 49 of Set 12 | merida
# Processing Record 50 of Set 12 | zapolyarnyy
# Processing Record 1 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 2 of Set 13 | flin flon
# Processing Record 3 of Set 13 | manhuacu
# Processing Record 4 of Set 13 | majene
# Processing Record 5 of Set 13 | sohag
# Processing Record 6 of Set 13 | carlyle
# Processing Record 7 of Set 13 | islamkot
# Processing Record 8 of Set 13 | sidney
# Processing Record 9 of Set 13 | sur
# Processing Record 10 of Set 13 | marystown
# Processing Record 11 of Set 13 | corinth
# Processing Record 12 of Set 13 | krasnoselkup
# Processing Record 13 of Set 13 | qazigund
# Processing Record 14 of Set 13 | araguatins
# City not found. Skipping...
# Processing Record 15 of Set 13 | sibolga
# Processing Record 16 of Set 13 | genhe
# Processing Record 17 of Set 13 | roald
# Processing Record 18 of Set 13 | bereda
# Processing Record 19 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 13 | tazovskiy
# Processing Record 21 of Set 13 | jelgava
# Processing Record 22 of Set 13 | kerema
# Processing Record 23 of Set 13 | kendari
# Processing Record 24 of Set 13 | grand-bourg
# Processing Record 25 of Set 13 | nabire
# Processing Record 26 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 13 | rio tercero
# Processing Record 28 of Set 13 | kuminskiy
# Processing Record 29 of Set 13 | lokosovo
# Processing Record 30 of Set 13 | teahupoo
# Processing Record 31 of Set 13 | twentynine palms
# Processing Record 32 of Set 13 | muravlenko
# Processing Record 33 of Set 13 | jinchang
# Processing Record 34 of Set 13 | zarand
# Processing Record 35 of Set 13 | sao gabriel da cachoeira
# Processing Record 36 of Set 13 | kaniama
# Processing Record 37 of Set 13 | gaozhou
# Processing Record 38 of Set 13 | mana
# Processing Record 39 of Set 13 | tahoua
# Processing Record 40 of Set 13 | buchanan
# Processing Record 41 of Set 13 | berbera
# Processing Record 42 of Set 13 | numata
# Processing Record 43 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 44 of Set 13 | bemidji
# Processing Record 45 of Set 13 | paraiso
# Processing Record 46 of Set 13 | tanggu
# Processing Record 47 of Set 13 | williston
# Processing Record 48 of Set 13 | salinopolis
# Processing Record 49 of Set 13 | kita
# Processing Record 50 of Set 13 | wajima
# Processing Record 1 of Set 14 | mataram
# Processing Record 2 of Set 14 | guane
# Processing Record 3 of Set 14 | conceicao do araguaia
# Processing Record 4 of Set 14 | yatou
# Processing Record 5 of Set 14 | kiama
# Processing Record 6 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 14 | puerto maldonado
# Processing Record 8 of Set 14 | poddorye
# Processing Record 9 of Set 14 | bakuriani
# Processing Record 10 of Set 14 | montijo
# Processing Record 11 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 14 | okha
# Processing Record 13 of Set 14 | sao joao do piaui
# Processing Record 14 of Set 14 | ahipara
# Processing Record 15 of Set 14 | krasnyy chikoy
# Processing Record 16 of Set 14 | bhatkal
# Processing Record 17 of Set 14 | christchurch
# Processing Record 18 of Set 14 | cap malheureux
# Processing Record 19 of Set 14 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 20 of Set 14 | yarim
# Processing Record 21 of Set 14 | chowchilla
# Processing Record 22 of Set 14 | keflavik
# Processing Record 23 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 14 | matara
# Processing Record 25 of Set 14 | carinhanha
# Processing Record 26 of Set 14 | san juan
# Processing Record 27 of Set 14 | kaeo
# Processing Record 28 of Set 14 | tekkali
# Processing Record 29 of Set 14 | praya
# Processing Record 30 of Set 14 | ucluelet
# Processing Record 31 of Set 14 | moindou
# Processing Record 32 of Set 14 | bani walid
# Processing Record 33 of Set 14 | mogocha
# Processing Record 34 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 14 | puerto del rosario
# Processing Record 36 of Set 14 | sovetskiy
# Processing Record 37 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 38 of Set 14 | san quintin
# Processing Record 39 of Set 14 | arrifes
# Processing Record 40 of Set 14 | north platte
# Processing Record 41 of Set 14 | quimperle
# Processing Record 42 of Set 14 | georgiyevskoye
# Processing Record 43 of Set 14 | falkenberg
# Processing Record 44 of Set 14 | byron bay
# Processing Record 45 of Set 14 | baracoa
# Processing Record 46 of Set 14 | jizan
# Processing Record 47 of Set 14 | nioro
# Processing Record 48 of Set 14 | opuwo
# Processing Record 49 of Set 14 | martapura
# Processing Record 50 of Set 14 | elko
# Processing Record 1 of Set 15 | kwekwe
# Processing Record 2 of Set 15 | kabalo
# Processing Record 3 of Set 15 | bethanien
# Processing Record 4 of Set 15 | stephenville crossing
# Processing Record 5 of Set 15 | realeza
# Processing Record 6 of Set 15 | teknaf
# Processing Record 7 of Set 15 | terrace bay
# Processing Record 8 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 15 | saint-marc
# Processing Record 10 of Set 15 | mbaiki
# Processing Record 11 of Set 15 | grimma
# Processing Record 12 of Set 15 | two hills
# Processing Record 13 of Set 15 | sabya
# Processing Record 14 of Set 15 | amahai
# Processing Record 15 of Set 15 | saint-ambroise
# Processing Record 16 of Set 15 | san juan del sur
# Processing Record 17 of Set 15 | coihaique
# Processing Record 18 of Set 15 | ravanusa
# Processing Record 19 of Set 15 | kargil
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cape Town -33.9258   18.4232     62.11        78           0
# 1   Punta Arenas -53.1500  -70.9167     46.11        93          99
# 2    Port Alfred -33.5906   26.8910     65.17        93          49
# 3        Mataura -46.1927  168.8643     69.48        50           0
# 4  Leningradskiy  69.3833  178.4167      1.29        86           8
# 5         Dwarka  22.2394   68.9678     82.63        58           6
# 6       Jiangyou  31.7667  104.7167     65.55        48           8
# 7     Port Hardy  50.6996 -127.4199     46.58        87         100
# 8        Salalah  17.0151   54.0924     82.49        37         100
# 9      Upernavik  72.7868  -56.1549     14.41        88         100
#
#    Wind Speed Country                 Date Current Description
# 0        3.44      ZA  2022-03-27 03:54:58           clear sky
# 1        9.13      CL  2022-03-27 03:58:46     overcast clouds
# 2        8.52      ZA  2022-03-27 03:58:46    scattered clouds
# 3        3.22      NZ  2022-03-27 03:58:47           clear sky
# 4        1.43      RU  2022-03-27 03:58:47           clear sky
# 5        8.77      IN  2022-03-27 03:57:30           clear sky
# 6        7.63      CN  2022-03-27 03:58:48           clear sky
# 7        3.44      CA  2022-03-27 03:58:48     overcast clouds
# 8        1.50      OM  2022-03-27 03:58:49     overcast clouds
# 9        6.46      GL  2022-03-27 03:58:49     overcast clouds

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", 
                           "Wind Speed", "Current Description"]]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Cape Town      ZA -33.9258   18.4232     62.11        78
# 1        Punta Arenas      CL -53.1500  -70.9167     46.11        93
# 2         Port Alfred      ZA -33.5906   26.8910     65.17        93
# 3             Mataura      NZ -46.1927  168.8643     69.48        50
# 4       Leningradskiy      RU  69.3833  178.4167      1.29        86
# ..                ...     ...      ...       ...       ...       ...
# 653    Saint-Ambroise      CA  48.5501  -71.3324     30.74        99
# 654  San Juan Del Sur      NI  11.2529  -85.8705     78.26        73
# 655         Coihaique      CL -45.5752  -72.0662     39.38        92
# 656          Ravanusa      IT  37.2667   13.9690     52.38        76
# 657            Kargil      IN  34.5667   76.1000     23.81        45
#
#      Cloudiness  Wind Speed Current Description
# 0             0        3.44           clear sky
# 1            99        9.13     overcast clouds
# 2            49        8.52    scattered clouds
# 3             0        3.22           clear sky
# 4             8        1.43           clear sky
# ..          ...         ...                 ...
# 653         100        2.57          light snow
# 654          43       23.60    scattered clouds
# 655          20       10.02          few clouds
# 656          84       19.04       broken clouds
# 657           0        1.39           clear sky
#
# [658 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
